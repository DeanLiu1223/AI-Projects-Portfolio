# %%
# !pip install scrapy

# %%
# !scrapy runspider udn.py -a keyword="行為" -o keyword1.jl
# !scrapy runspider udn.py -a keyword="習慣" -o keyword2.jl
# !scrapy runspider udn.py -a keyword="創新" -o others.jl
# Out:
# 2025-04-17 01:30:35 [scrapy.utils.log] INFO: Scrapy 2.12.0 started (bot: scrapybot)
# 2025-04-17 01:30:35 [scrapy.utils.log] INFO: Versions: lxml 5.3.2.0, libxml2 2.12.10, cssselect 1.3.0, parsel 1.10.0, w3lib 2.3.1, Twisted 24.11.0, Python 3.11.12 (main, Apr  9 2025, 08:55:54) [GCC 11.4.0], pyOpenSSL 24.2.1 (OpenSSL 3.3.2 3 Sep 2024), cryptography 43.0.3, Platform Linux-6.1.85+-x86_64-with-glibc2.35
# 2025-04-17 01:30:35 [udn_keyword] INFO: 收到的搜尋關鍵字: 行為
# 2025-04-17 01:30:35 [scrapy.addons] INFO: Enabled addons:
# []
# 2025-04-17 01:30:35 [scrapy.extensions.telnet] INFO: Telnet Password: 0e16753e720b7fb4
# 2025-04-17 01:30:35 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2025-04-17 01:30:35 [scrapy.crawler] INFO: Overridden settings:
# {'DOWNLOAD_DELAY': 3,
# ...

# %%
#!scrapy runspider udn.py -a keyword="行為 習慣" -o output.jl
# Out:
# 2025-04-17 01:44:22 [scrapy.utils.log] INFO: Scrapy 2.12.0 started (bot: scrapybot)
# 2025-04-17 01:44:22 [scrapy.utils.log] INFO: Versions: lxml 5.3.2.0, libxml2 2.12.10, cssselect 1.3.0, parsel 1.10.0, w3lib 2.3.1, Twisted 24.11.0, Python 3.11.12 (main, Apr  9 2025, 08:55:54) [GCC 11.4.0], pyOpenSSL 24.2.1 (OpenSSL 3.3.2 3 Sep 2024), cryptography 43.0.3, Platform Linux-6.1.85+-x86_64-with-glibc2.35
# 2025-04-17 01:44:23 [udn_keyword] INFO: 收到的搜尋關鍵字: 行為 習慣
# 2025-04-17 01:44:23 [scrapy.addons] INFO: Enabled addons:
# []
# 2025-04-17 01:44:23 [scrapy.extensions.telnet] INFO: Telnet Password: 4a25037103af0001
# 2025-04-17 01:44:23 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2025-04-17 01:44:23 [scrapy.crawler] INFO: Overridden settings:
# {'DOWNLOAD_DELAY': 3,
# ...
